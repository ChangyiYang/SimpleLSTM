# %%
# this file is used to visualize the fluence
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
def visualize_fluence(path, column_name):
    data = pd.read_csv(path)
    data = data[data['fuel'] == True]

    plt.hist(data[column_name])

    plt.ylabel('count')
    plt.xlabel('flux')

    return data

y = [20,21,22,23,24,27,28,29,31,32,34]

# %%
column_name = 'flux_pebbles_fast'
for i in y:
    data = visualize_fluence(f'./data/data_{i}.csv', column_name)

# %%
column_name = 'flux_pebbles_thermal'
for i in y:
    data = visualize_fluence(f'./data/data_{i}.csv', column_name)

# %%
column_name = 'integrated_flux_pebbles_thermal'
for i in y:
    data = visualize_fluence(f'./data/data_{i}.csv', column_name)

# %%
column_name = 'integrated_flux_pebbles_fast'
for i in y:
    data = visualize_fluence(f'./data/data_{i}.csv', column_name)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'x', 'y', 'z', 'r', 'id', 'dist', 'r_dist', 'azim_angle',
#        'fuel', 'initial', 'passes', 'recirculated', 'discarded',
#        'residence_time', 'pass_residence_time', 'pass_burnup',
#        'insertion_step', 'avg_r_dist', 'burnup', 'flux_pebbles_thermal',
#        'flux_pebbles_thermal_rel_unc', 'integrated_flux_pebbles_thermal',
#        'integrated_flux_pebbles_thermal_unc',
#        'integrated_flux_pebbles_thermal_rel_unc', 'flux_pebbles_fast',
#        'flux_pebbles_fast_rel_unc', 'integrated_flux_pebbles_fast',
#        'integrated_flux_pebbles_fast_unc',
#        'integrated_flux_pebbles_fast_rel_unc', 'power_pebbles',
#        'power_pebbles_rel_unc', 'integrated_power_pebbles',
#        'integrated_power_pebbles_unc', 'integrated_power_pebbles_rel_unc',
#        '922350', '922380', '942390', '942410', '541350', '551370'],
#       dtype='object')
