# %% [markdown]
# # Data Inspection

# %%
import pandas as pd  
import numpy as np

data = pd.read_csv("./Processed Data/HxF_three.csv")

# %%
data.shape
# Out:
# (1357, 644)

# %%
data.iloc[0:]
# Out:
#       1.022314820782549427e+00  0.000000000000000000e+00  \
# 0                     1.024112                       1.0
# 1                     1.023133                       2.0
# 2                     1.022788                       3.0
# 3                     1.023063                       4.0
# 4                     1.022037                       5.0
# ...                        ...                       ...
# 1352                       NaN                     589.0
# 1353                       NaN                     590.0
# 1354                       NaN                     591.0
# 1355                       NaN                     592.0
# 1356                       NaN                     593.0
#
#       7.807076173992638720e+17  4.308721892144159317e+09  \
# 0                 8.047827e+17              4.111453e+09
# 1                 7.716132e+17              4.355860e+09
# 2                 7.644949e+17              4.105878e+09
# ...

# %%
data_90 = pd.read_csv("./Processed Data/HxF_90pow_offset_20.csv")
data_90.shape
# Out:
# (584, 322)

# %%
data_100 = pd.read_csv("./Processed Data/HxF_100pow_offset_20.csv")
data_100.shape
# Out:
# (180, 322)

# %%
data_110 = pd.read_csv("./Processed Data/HxF_110pow_offset_20.csv")
data_110.shape
# Out:
# (593, 322)

# %%
data = np.loadtxt(f'./Processed Data/HxF_90pow_offset_20.csv', delimiter= ',', dtype= np.float64)
data.shape
# Out:
# (585, 322)

# %%
data = np.loadtxt(f'./Processed Data/HxF_100pow_offset_20.csv', delimiter= ',', dtype= np.float64)

# %%
data = np.loadtxt(f'./Processed Data/HxF_110pow_offset_20.csv', delimiter= ',', dtype= np.float64)

# %%
data = np.loadtxt(f'./Processed Data/HxF_three.csv', delimiter= ',', dtype= np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\11835\Documents\GitHub\SimpleLSTM\Data_inspection.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/11835/Documents/GitHub/SimpleLSTM/Data_inspection.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> data = np.loadtxt(f'./Processed Data/HxF_three.csv', delimiter= ',', dtype= np.float64)
#
# File c:\Users\11835\anaconda3\lib\site-packages\numpy\lib\npyio.py:1338, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1335 if isinstance(delimiter, bytes):
#    1336     delimiter = delimiter.decode('latin1')
# -> 1338 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1339             converters=converters, skiplines=skiprows, usecols=usecols,
#    1340             unpack=unpack, ndmin=ndmin, encoding=encoding,
# ...

# %%
data = pd.read_csv("./HxF data/Equilibrium (100_ power)/HxF_HTR10_equilibrium_average_actual_concentrations_features.csv")

data.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0        Ag-109       Ag-109m       Ag-110m        Ag-111  \
# 0             0  7.607809e+17  4.245792e+09  1.971869e+15  1.719444e+15
# 1             1  7.635924e+17  4.152834e+09  1.984385e+15  1.712936e+15
# 2             2  7.543827e+17  4.115040e+09  1.946213e+15  1.719773e+15
# 3             3  7.745997e+17  3.975388e+09  2.007313e+15  1.700929e+15
# 4             4  7.740545e+17  4.098361e+09  2.002300e+15  1.718999e+15
# ..          ...           ...           ...           ...           ...
# 196         196  8.042008e+17  4.168901e+09  2.099102e+15  1.708451e+15
# 197         197  7.624006e+17  4.136736e+09  1.974475e+15  1.731037e+15
# 198         198  7.752452e+17  3.935462e+09  2.007975e+15  1.701693e+15
# 199         199  7.841111e+17  3.988722e+09  2.038578e+15  1.709246e+15
# 200         200  7.673713e+17  4.131666e+09  1.987045e+15  1.722514e+15
#
# ...
