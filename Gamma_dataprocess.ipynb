# %% [markdown]
# ## Gamma
# This file is used to do the data processing for the gamma data.

# %%
# some imports

import pandas as pd   
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# load the file 



# Specify the path to your .pkl file
file_path = "./Gamma Data/gammas_detected_0.pkl"

# Open the .pkl file in binary read mode
with open(file_path, "rb") as file:
    # Load the data from the file
    data = pickle.load(file)

# Now, 'data' contains the Python object that was serialized in the .pkl file
# You can use 'data' as you would with any other Python object

# %%
# do some peeeking

df = pd.read_pickle("./Gamma Data/gammas_detected_0.pkl")

df.shape
# Out:
# (253, 516816)

# %%
plt.plot(data.iloc[:,0])
