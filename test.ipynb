# %%
import pandas as pd    


data = pd.read_csv("./Gamma Data/cycle_352.csv")

data
# Out:
#      Step      time     passes  recirculated  discarded      keff  \
# 0       0     0.000   0.000000           NaN        NaN       NaN
# 1       1    12.512   0.050008        1563.0      382.0  0.993459
# 2       2    25.024   0.100016        1563.0      358.0  0.996394
# 3       3    37.536   0.150024        1563.0      389.0  0.996537
# 4       4    50.048   0.200032        1563.0      388.0  1.000258
# ..    ...       ...        ...           ...        ...       ...
# 348   348  4354.176  17.402782        1563.0      326.0  1.015423
# 349   349  4366.688  17.452790        1563.0      315.0  1.015630
# 350   350  4379.200  17.502798        1563.0      320.0  1.015569
# 351   351  4391.712  17.552806        1563.0      327.0  1.016668
# 352   352  4404.224  17.602814        1563.0      341.0  1.015148
#
#      keff_relative_uncertainty  keff_absolute_uncertainty  neutrons_per_cycle  \
# 0                          NaN                        NaN               50000
# ...
